# %% [markdown]
# # Trees

# %% [markdown]
#  Binary Tree Problems  Pattern-wise (with ROI Tags)

# %% [markdown]
# 1. Traversals
#
#  Core Techniques: DFS Recursion / Stack; BFS with Queue
# | # | Problem                           | Platform | Companies         | LC #    | Difficulty | Importance |
# | - | --------------------------------- | -------- | ----------------- | ------- | ---------- | ---------- |
# | 1 | Binary Tree Inorder Traversal  (DFS)   | LeetCode | Amazon, Microsoft | LC 94   | Easy       |  High     |
# | 2 | Binary Tree Preorder Traversal    (DFS)| LeetCode | Google, Facebook  | LC 144  | Easy       |  High     |
# | 3 | Binary Tree Postorder Traversal  (DFS) | LeetCode | Amazon, Adobe     | LC 145  | Easy       |  High     |
# | 4 | Binary Tree Level Order Traversal (BFS) 2 methods -Null Marker Method , level Size tracking method | LeetCode | Amazon, Google    | LC 102  | Medium     |  High     |
# | 5 | Zigzag Level Order Traversal      (BFS) Direct Application | LeetCode | Facebook, Apple   | LC 103  | Medium     |  High     |
# | 6 | Reverse Level Order Traversal     (BFS)Direct Application | LeetCode | Microsoft         | LC 107  | Medium     |  Medium   |
# | 7 | Morris Inorder Traversal          | LeetCode | Facebook          | Classic | Medium     |  Medium   |

# %% [markdown]
# 2. Basic Properties
#
#  Core Techniques: Simple recursion (height, depth, mirror), divide & conquer
# | #  | Problem                      | Platform | Companies         | LC #    | Difficulty | Importance |
# | -- | ---------------------------- | -------- | ----------------- | ------- | ---------- | ---------- |
# | 8  | Maximum Depth of Binary Tree | LeetCode | Amazon, Bloomberg | LC 104  | Easy       |  High     |
# | 9  | Minimum Depth of Binary Tree | LeetCode | Meta              | LC 111  | Easy       |  Medium   |
# | 10 | Count Complete Tree Nodes    | LeetCode | Google            | LC 222  | Medium     |  Medium   |
# | 11 | Invert Binary Tree           | LeetCode | Google, Microsoft | LC 226  | Easy       |  Medium   |

# %% [markdown]
# 3. Structural Checks
#
#  Core Techniques: Tree Equality, Symmetry, Balanced Check, Subtree Matching
#
# | #  | Problem                 | Platform | Companies        | LC #   | Difficulty | Importance |
# | -- | ----------------------- | -------- | ---------------- | ------ | ---------- | ---------- |
# | 13 | Symmetric Tree          | LeetCode | Amazon, Google   | LC 101 | Easy       |  High     |
# | 14 | Balanced Binary Tree    | LeetCode | Adobe, Microsoft | LC 110 | Easy       |  High     |
# | 15 | Same Tree               | LeetCode | Facebook         | LC 100 | Easy       |  Medium   |
# | 16 | Subtree of Another Tree | LeetCode | Amazon           | LC 572 | Easy       |  Medium   |
# | 17 | Cousins in Binary Tree  | LeetCode | Google           | LC 993 | Easy       |  Medium   |

# %% [markdown]
# 4. Path Problems\
# 4.1 Root-to-Leaf Paths
#
# | #  | Problem                  | Platform | Companies         | LC #   | Difficulty | Importance |
# | -- | ------------------------ | -------- | ----------------- | ------ | ---------- | ---------- |
# | 18 | Path Sum I               | LeetCode | Amazon, Microsoft | LC 112 | Easy       |  High     |
# | 19 | Path Sum II              | LeetCode | Google, Adobe     | LC 113 | Medium     |  High     |
# | 20 | Sum Root to Leaf Numbers | LeetCode | Google            | LC 129 | Medium     |  Medium   |
#
# 4.2 Any Node-to-Any Node Paths
#
# | #  | Problem                      | Platform | Companies        | LC #   | Difficulty | Importance |
# | -- | ---------------------------- | -------- | ---------------- | ------ | ---------- | ---------- |
# | 21 | Diameter of Binary Tree      | LeetCode | Amazon, Apple    | LC 543 | Easy       |  High     |
# | 22 | Binary Tree Maximum Path Sum | LeetCode | Google, Facebook | LC 124 | Hard       |  High     |
#
# 4.3 Special Path Variants
#
# | #  | Problem                         | Platform | Companies      | LC #    | Difficulty | Importance |
# | -- | ------------------------------- | -------- | -------------- | ------- | ---------- | ---------- |
# | 23 | Path Sum III (prefix sum)       | LeetCode | Facebook       | LC 437  | Medium     |  Medium   |
# | 24 | Longest ZigZag Path             | LeetCode | Google, Amazon | LC 1372 | Medium     |  Medium   |
# | 25 | Pseudo-Palindromic Paths        | LeetCode | Google         | LC 1457 | Medium     |  Medium   |
# | 26 | Count Good Nodes in Binary Tree | LeetCode | Amazon         | LC 1448 | Medium     |  Medium   |

# %% [markdown]
# 5. Ancestors, LCA & Distance
#
#  Core Techniques: LCA (DFS / BST) + BFS with parent tracking
#
# | #  | Problem                             | Platform      | Companies           | LC #    | Difficulty | Importance |
# | -- | ----------------------------------- | ------------- | ------------------- | ------- | ---------- | ---------- |
# | 27 | LCA of Binary Tree                  | LeetCode      | Amazon, Microsoft   | LC 236  | Medium     |  High     |
# | 28 | LCA of BST                          | LeetCode      | Google, Microsoft   | LC 235  | Easy       |  High     |
# | 29 | All Nodes Distance K in Binary Tree | LeetCode      | Google, Amazon      | LC 863  | Medium     |  High     |
# | 30 | Burning Tree                        | GFG           | Microsoft, Flipkart | Classic | Hard       |  High     |
# | 31 | Distance Between Two Nodes in BST   | GFG/Interview | Amazon              | Classic | Medium     |  Medium   |

# %% [markdown]
# 6. BST-Specific Problems
#
#  Core Techniques: Recursion / Inorder property
#
# | #  | Problem                         | Platform | Companies        | LC #   | Difficulty | Importance |
# | -- | ------------------------------- | -------- | ---------------- | ------ | ---------- | ---------- |
# | 32 | Search in BST                   | LeetCode | Amazon           | LC 700 | Easy       |  High     |
# | 33 | Insert into BST                 | LeetCode | Google           | LC 701 | Medium     |  High     |
# | 34 | Delete Node in BST              | LeetCode | Amazon, Google   | LC 450 | Medium     |  High     |
# | 35 | Validate BST                    | LeetCode | Amazon, Google   | LC 98  | Medium     |  High     |
# | 36 | Kth Smallest in BST             | LeetCode | Microsoft, Apple | LC 230 | Medium     |  High     |
# | 37 | Convert Sorted Array to BST     | LeetCode | Adobe            | LC 108 | Easy       |  Medium   |
# | 38 | Convert BST to Greater Sum Tree | LeetCode | Google           | LC 538 | Medium     |  Medium   |
# | 39 | BST Iterator                    | LeetCode | Bloomberg, Meta  | LC 173 | Medium     |  High     |

# %% [markdown]
# 7. Tree Construction
#
#  Core Techniques: Divide & Conquer using traversals, recursion with bounds, BFS construction
#
# | #  | Problem                               | Platform | Companies      | LC #    | Difficulty | Importance |
# | -- | ------------------------------------- | -------- | -------------- | ------- | ---------- | ---------- |
# | 40 | Construct BT from Preorder & Inorder  | LeetCode | Amazon, Google | LC 105  | Medium     |  High     |
# | 41 | Construct BT from Inorder & Postorder | LeetCode | Microsoft      | LC 106  | Medium     |  High     |
# | 42 | Construct BST from Preorder           | LeetCode | Google         | LC 1008 | Medium     |  Medium   |
# | 43 | Construct from Level Order            | GFG      | TCS, Infosys   | Classic | Medium     |  Medium   |
# | 44 | Build Binary Tree from Parent Array   | GFG      | Amazon         | Classic | Medium     |  Medium   |

# %% [markdown]
# 8. Serialization & Deserialization
#
#  Core Techniques: Stringify Tree via Traversal and Rebuild
#
# | #  | Problem                             | Platform | Companies      | LC #   | Difficulty | Importance |
# | -- | ----------------------------------- | -------- | -------------- | ------ | ---------- | ---------- |
# | 45 | Serialize & Deserialize Binary Tree | LeetCode | Google, Amazon | LC 297 | Hard       |  High     |
# | 46 | Serialize & Deserialize BST         | LeetCode | Amazon         | LC 449 | Medium     |  Medium   |

# %% [markdown]
# 9. Transformations
#
#  Core Techniques: Restructuring node pointers
#
# | #  | Problem                            | Platform | Companies        | LC #       | Difficulty | Importance |
# | -- | ---------------------------------- | -------- | ---------------- | ---------- | ---------- | ---------- |
# | 47 | Flatten Binary Tree to Linked List | LeetCode | Amazon, Meta     | LC 114     | Medium     |  High     |
# | 48 | Binary Tree to DLL                 | GFG      | Adobe, Microsoft | Classic    | Medium     |  Medium   |
# | 49 | Populating Next Right Pointers     | LeetCode | Microsoft        | LC 116,117 | Medium     |  Medium   |
# | 50 | Binary Tree Upside Down            | LeetCode | Google           | LC 156     | Medium     |  Medium   |

# %% [markdown]
# 10. Views & Boundary Problems
#
#  Core Techniques: BFS with coordinates, queue level maps, boundary traversal
#
# | #  | Problem                     | Platform | Companies      | LC #    | Difficulty | Importance |
# | -- | --------------------------- | -------- | -------------- | ------- | ---------- | ---------- |
# | 51 | Right Side View             | LeetCode | Amazon         | LC 199  | Medium     |  High     |
# | 52 | Left Side View              | GFG      | Infosys, Wipro | Classic | Medium     |  Medium   |
# | 53 | Top View of Binary Tree     | GFG      | TCS, Amazon    | Classic | Medium     |  Medium   |
# | 54 | Bottom View of Binary Tree  | GFG      | TCS, Infosys   | Classic | Medium     |  Medium   |
# | 55 | Vertical Order Traversal    | LeetCode | Google, Amazon | LC 987  | Hard       |  Medium   |
# | 56 | Boundary Traversal          | GFG      | Infosys        | Classic | Medium     |  Medium   |
# | 57 | Diagonal Traversal          | GFG      | Wipro          | Classic | Medium     |  Medium   |
# | 58 | Vertical Sum in Binary Tree | GFG      | Infosys        | Classic | Medium     |  Medium   |

# %% [markdown]
# 11. Advanced Tree DP
#
#  Core Techniques: DP on tree states, subtree sums, structural optimization
#
# | #  | Problem                        | Platform | Companies    | LC #    | Difficulty | Importance |
# | -- | ------------------------------ | -------- | ------------ | ------- | ---------- | ---------- |
# | 59 | House Robber III               | LeetCode | Amazon, Meta | LC 337  | Medium     |  High     |
# | 60 | Path Sum IV                    | LeetCode | Google       | LC 666  | Medium     |  Medium   |
