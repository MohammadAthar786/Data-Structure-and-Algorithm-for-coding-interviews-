# %% [markdown]
# 1 Two Pointer Techniques
#
# | # | Problem                               | LC # | Pattern / Key Idea                           | Difficulty | ROI   |
# | - | ------------------------------------- | ---- | -------------------------------------------- | ---------- | ----- |
# | 1 | Middle of Linked List                 | 876  | Fast/Slow Pointers (Floyd's Tortoise & Hare) | Easy       |  |
# | 2 | Remove Nth Node From End              | 19   | Two Pointers with Gap                        | Easy       |  |
# | 3 | Intersection of Two Linked Lists      | 160  | Length Alignment Two Pointers                | Medium     |   |
# | 4 | Remove Duplicates from Sorted List II | 82   | Previous + Current Pointer                   | Medium     |   |
#
#
# 3 Cycle Detection & Manipulation
#
# | #  | Problem              | LC # | Pattern / Key Idea           | Difficulty | ROI   |
# | -- | -------------------- | ---- | ---------------------------- | ---------- | ----- |
# | 10 | Linked List Cycle    | 141  | Floyd's Algorithm            | Easy       |  |
# | 11 | Linked List Cycle II | 142  | Floyd + Math Proof           | Medium     |  |
#
#
#
# 2 Reversal Patterns
#
# | # | Problem                   | LC # | Pattern / Key Idea              | Difficulty | ROI   |
# | - | ------------------------- | ---- | ------------------------------- | ---------- | ----- |
# | 5 | Reverse Linked List       | 206  | Three Pointer Technique         | Easy       |  |
# | 6 | Reverse Linked List II    | 92   | Partial Reversal + Reconnection | Medium     |  |
# | 7 | Reverse Nodes in k-Group  | 25   | Group-wise Reversal             | Medium     |  |
# | 8 | Swap Nodes in Pairs       | 24   | Pairwise Manipulation           | Medium     |   |
# | 9 | Reverse Alternate K Nodes |     | Conditional Group Reversal      | Hard       |    |

# %% [markdown]
# 4 Merge & Sort Operations
#
# | #  | Problem                | LC # | Pattern / Key Idea                 | Difficulty | ROI   |
# | -- | ---------------------- | ---- | ---------------------------------- | ---------- | ----- |
# | 13 | Merge Two Sorted Lists | 21   | Two Pointer Merge                  | Easy       |  |
# | 14 | Sort List              | 148  | Divide & Conquer + Merge           | Medium     |  |
# | 15 | Merge k Sorted Lists   | 23   | Priority Queue / Divide & Conquer  | Medium     |  |
# | 16 | Add Two Numbers        | 2    | Digit-by-Digit Addition with Carry | Medium     |   |
# | 17 | Add Two Numbers II     | 445  | Stack or List Reversal             | Medium     |    |

# %% [markdown]
# 5 List Manipulation & Construction
#
# | #  | Problem                            | LC # | Pattern / Key Idea         | Difficulty | ROI  |
# | -- | ---------------------------------- | ---- | -------------------------- | ---------- | ---- |
# | 18 | Remove Duplicates from Sorted List | 83   | Single Pass Comparison     | Easy       |   |
# | 19 | Palindrome Linked List             | 234  | Reverse Half + Compare     | Easy       |  |
# | 20 | Reorder List                       | 143  | Middle + Reverse + Merge   | Medium     |  |
# | 21 | Partition List                     | 86   | Two Separate Lists + Merge | Medium     |   |
# | 22 | Rotate List                        | 61   | Tail + Cycle + Break       | Medium     |   |
# | 23 | Delete Node in a Linked List       | 237  | Copy Next Node's Data      | Medium     |    |

# %% [markdown]
# 6 Advanced Techniques
#
# | #  | Problem                               | LC # | Pattern / Key Idea           | Difficulty | ROI   |
# | -- | ------------------------------------- | ---- | ---------------------------- | ---------- | ----- |
# | 24 | Copy List with Random Pointer         | 138  | HashMap / Interweaving       | Hard       |   |
# | 25 | Flatten Multilevel Doubly Linked List | 430  | DFS / Stack Traversal        | Hard       |    |
# | 26 | LRU Cache                             | 146  | HashMap + Doubly Linked List | Hard       |  |
# | 27 | LFU Cache                             | 460  | Multi-DS Coordination        | Hard       |    |

# %% [markdown]
# 7 Design & Implementation
#
# | #  | Problem                 | LC # | Pattern / Key Idea            | Difficulty | ROI |
# | -- | ----------------------- | ---- | ----------------------------- | ---------- | --- |
# | 28 | Design Browser History  | 1472 | Doubly Linked List Navigation | Medium     |  |
# | 29 | All O(1) Data Structure | 432  | Linked List + HashMap Design  | Hard       |   |
